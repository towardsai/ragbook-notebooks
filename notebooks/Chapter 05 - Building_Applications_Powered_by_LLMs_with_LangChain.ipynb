# %% [markdown]
# <a href="https://colab.research.google.com/github/towardsai/ragbook-notebooks/blob/main/notebooks/Chapter%2005%20-%20Building_Applications_Powered_by_LLMs_with_LangChain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langchain==0.0.208 openai==0.27.8 python-dotenv pypdf

# %%
import os

# os.environ["OPENAI_API_KEY"]="OPENAI_API_KEY"

from google.colab import userdata
os.environ["OPENAI_API_KEY"]= userdata.get('OPENAI_API_KEY')

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)

chat = ChatOpenAI(model_name="gpt-4.1-mini", temperature=0)

template = "You are an assistant that helps users find information about movies."
system_message_prompt = SystemMessagePromptTemplate.from_template(template)
human_template = "Find information about the movie {movie_title}."
human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)

chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, human_message_prompt])

response = chat(chat_prompt.format_prompt(movie_title="Inception").to_messages())

print(response.content)
# Out:
# "Inception" is a 2010 science fiction thriller film written and directed by Christopher Nolan. The movie stars Leonardo DiCaprio as Dom Cobb, a skilled thief who specializes in entering people's dreams to steal secrets from their subconscious. The film explores themes of dreams, reality, and the subconscious mind.
#
# Key details about "Inception":
# - Director: Christopher Nolan
# - Writer: Christopher Nolan
# - Main Cast: Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen Page, Tom Hardy, Ken Watanabe, Cillian Murphy, Marion Cotillard, Michael Caine
# - Genre: Science Fiction, Thriller, Action
# - Release Date: July 16, 2010 (USA)
# - Runtime: Approximately 148 minutes
# - Plot Summary: Dom Cobb is offered a chance to have his criminal history erased as payment for the implantation of another person's idea into a target's subconscious, a process known as "inception." The film follows Cobb and his team as they attempt this complex heist within the layers of dreams.
# - Awards: "Inception" won 4 Academy Awards (Oscars) for Best Cinematography, Best Sound Editing, Best Sound Mixing, and Best Visual Effects. It was also nominated for Best Picture and Best Original Screenplay, among others.
#
# If you want more specific information such as reviews, box office performance, or detailed plot analysis, please let me know!

# %% [markdown]
# # ====

# %%
# Import necessary modules
from langchain.chat_models import ChatOpenAI
from langchain import PromptTemplate
from langchain.chains.summarize import load_summarize_chain
from langchain.document_loaders import PyPDFLoader

# %%
# Initialize language model
llm = ChatOpenAI(model_name="gpt-4.1-mini", temperature=0)

# %%
# Load the summarization chain
summarize_chain = load_summarize_chain(llm)

# %% [markdown]
# Download file from: https://www.cheat-sheets.org/saved-copy/The%20One%20Page%20Linux%20Manual.pdf

# %%
# !wget https://www.cheat-sheets.org/saved-copy/The%20One%20Page%20Linux%20Manual.pdf
# Out:
# --2026-01-22 15:04:41--  https://www.cheat-sheets.org/saved-copy/The%20One%20Page%20Linux%20Manual.pdf
# Resolving www.cheat-sheets.org (www.cheat-sheets.org)... 90.156.201.79, 90.156.201.26, 90.156.201.114, ...
# Connecting to www.cheat-sheets.org (www.cheat-sheets.org)|90.156.201.79|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 96538 (94K) [application/pdf]
# Saving to: ‘The One Page Linux Manual.pdf.1’
#
# The One Page Linux  100%[===================>]  94.28K   255KB/s    in 0.4s
#
# 2026-01-22 15:04:42 (255 KB/s) - ‘The One Page Linux Manual.pdf.1’ saved [96538/96538]

# %%
# Load the document using PyPDFLoader
document_loader = PyPDFLoader(file_path="./The One Page Linux Manual.pdf")
document = document_loader.load()

# %%
# Summarize the document
summary = summarize_chain(document)

# %%
print(summary['output_text'])
# Out:
# This one-page Linux manual (Version 3.0, May 1999) provides a quick reference to essential Linux commands and concepts. It covers system startup and shutdown commands, mounting and unmounting file systems, file searching (find, locate, grep), file management (ls, rm, cp, mv, cat, head, tail), software installation with rpm and tar, user administration (adduser, passwd, su), and useful system utilities (ifconfig, ps, kill). It also explains key configuration files (e.g., /etc/fstab, /etc/hosts, /etc/inittab), file permissions with chmod, X Window System commands and shortcuts, and printing commands. The guide offers practical tips for troubleshooting, system maintenance, and basic Linux operation.

# %% [markdown]
# # =====

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.chat_models import ChatOpenAI

prompt = PromptTemplate(template="Question: {question}\nAnswer:", input_variables=["question"])

llm = ChatOpenAI(model_name="gpt-4.1-mini", temperature=0)
chain = LLMChain(llm=llm, prompt=prompt)

# %%
chain.run("what is the meaning of life?")
# Out:
# 'The meaning of life is a deeply personal and philosophical question that has been explored throughout history. Different perspectives offer various answers:\n\n- **Philosophical:** Some suggest that life’s meaning is something we create through our actions, relationships, and personal growth.\n- **Religious/Spiritual:** Many traditions believe life’s purpose is connected to fulfilling a divine plan, spiritual enlightenment, or moral development.\n- **Scientific:** From a biological standpoint, the purpose of life can be seen as survival and reproduction to continue the species.\n- **Existential:** Existentialists often argue that life has no inherent meaning, and it’s up to each individual to find or create their own meaning.\n\nUltimately, the meaning of life varies for each person and can evolve over time based on experiences and beliefs.'
