# %% [markdown]
# <a href="https://colab.research.google.com/github/towardsai/ragbook-notebooks/blob/main/notebooks/Chapter%2011%20-%20Benchmark_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers===4.34.0 intel_extension_for_pytorch===2.0.100
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 22.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 MB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 18.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 22.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 74.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 51.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 23.6 MB/s eta 0:00:00

# %%
import time
import torch; torch.set_num_threads(8); # Use all the cores.

# %% [markdown]
# # Vanila

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("facebook/opt-1.3b", cache_dir="./opt-1.3b")

# %%
from transformers import AutoModelForCausalLM

model = AutoModelForCausalLM.from_pretrained(
    "facebook/opt-1.3b", cache_dir="./opt-1.3b"#, load_in_8bit=True
)

# %%
# inputs = tokenizer(["What does life mean? Describe in great details.", "What does life mean? Describe in great details.", "What does life mean? Describe in great details.", "What does life mean? Describe in great details."], return_tensors="pt")
inputs = tokenizer("""What does life mean? Describe in great details.""", return_tensors="pt")

# %%
start = time.time()
generation_output1 = model.generate(**inputs,
                                    return_dict_in_generate=True,
                                    output_scores=True,
                                    min_length=512,
                                    max_length=512,
                                    num_beams=1)
end = time.time()
print(end - start)
# Out:
# 268.7238254547119

# %%
tokenizer.decode(generation_output1.sequences[0])
# Out:
# "</s>What does life mean? Describe in great details.\nI'm not sure. I'm not sure what I want to do with my life. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I grow up. I'm not sure what I want to be when I g
# ...

# %% [markdown]
# # Quantized (CLI)

# %%
# !pip install git+https://github.com/huggingface/optimum-intel.git@v1.11.0
# !pip install neural_compressor===2.2.1
# !pip install onnx===1.14.1
# !optimum-cli inc quantize --model facebook/opt-1.3b --output opt1.3b-quantized

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("facebook/opt-1.3b")

# %%
from optimum.intel import INCModelForCausalLM


model_name = "./opt1.3b-quantized"
model = INCModelForCausalLM.from_pretrained(model_name)

# %%
# inputs = tokenizer(["What does life mean? Describe in great details.", "What does life mean? Describe in great details.", "What does life mean? Describe in great details.", "What does life mean? Describe in great details."], return_tensors="pt")
inputs = tokenizer("""What does life mean? Describe in great details.""", return_tensors="pt")

# %%
start = time.time()
generation_output1 = model.generate(**inputs,
                                    return_dict_in_generate=True,
                                    output_scores=True,
                                    min_length=512,
                                    max_length=512,
                                    num_beams=4,
                                    do_sample=True,
                                    repetition_penalty=1.5)
end = time.time()
print(end - start)

# %% [markdown]
# # Quantized (Code)
# Cannot be executed on Google Colab due to memory constraints.

# %%
# !pip install -q git+https://github.com/huggingface/optimum-intel.git@v1.11.0
# !pip install -q onnx===1.14.1 neural_compressor===2.2.1
# !pip install -q evaluate===0.4.0 datasets===2.14.5 transformers===4.34.0
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.0/301.0 kB 4.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 56.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 33.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 55.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 19.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 14.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.4 MB/s eta 0:00:00
# ...

# %%
import evaluate
from optimum.intel import INCQuantizer
from datasets import load_dataset
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline
from neural_compressor.config import AccuracyCriterion, TuningCriterion, PostTrainingQuantConfig

# %%
model_name "aman-mehra/opt-1.3b-finetune-squad-ep-0.4-lr-2e-05-wd-0.01"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, cache_dir="./opt-1.3b")

# %%
model = AutoModelForQuestionAnswering.from_pretrained(model_name, cache_dir="./opt-1.3b")
# Out:
# ...
# Some weights of OPTForQuestionAnswering were not initialized from the model checkpoint at facebook/opt-1.3b and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
task_evaluator = evaluate.evaluator("question-answering")

# %%
eval_dataset = load_dataset("squad", split="validation", cache_dir="./squad-ds")
eval_dataset = eval_dataset.select(range(64)) # Ues a subset of dataset
# Out:
# ...
# Generating validation split:   0%|          | 0/10570 [00:00<?, ? examples/s]

# %%
qa_pipeline = pipeline("question-answering", model=model, tokenizer=tokenizer)

# %%
def eval_fn(model):
    qa_pipeline.model = model
    metrics = task_evaluator.compute(model_or_pipeline=qa_pipeline, data=eval_dataset, metric="squad")
    return metrics["f1"]

# %%
# Set the accepted accuracy loss to 5%
accuracy_criterion = AccuracyCriterion(tolerable_loss=0.05)

# Set the maximum number of trials to 10
tuning_criterion = TuningCriterion(max_trials=10)

quantization_config = PostTrainingQuantConfig(
    approach="dynamic", accuracy_criterion=accuracy_criterion, tuning_criterion=tuning_criterion
)

# %%
quantizer = INCQuantizer.from_pretrained(model, eval_fn=eval_fn)

# %%
quantizer.quantize(quantization_config=quantization_config, save_directory="opt1.3b-quantized")
# Out:
# 2023-10-11 15:30:46 [INFO] Start auto tuning.
# 2023-10-11 15:30:46 [INFO] Execute the tuning process due to detect the evaluation function.
# 2023-10-11 15:30:46 [INFO] Adaptor has 4 recipes.
# 2023-10-11 15:30:46 [INFO] 0 recipes specified by user.
# 2023-10-11 15:30:46 [INFO] 3 recipes require future tuning.
# 2023-10-11 15:30:46 [INFO] *** Initialize auto tuning
# 2023-10-11 15:30:46 [INFO] {
# 2023-10-11 15:30:46 [INFO]     'PostTrainingQuantConfig': {
# 2023-10-11 15:30:46 [INFO]         'AccuracyCriterion': {
# 2023-10-11 15:30:46 [INFO]             'criterion': 'relative',
# 2023-10-11 15:30:46 [INFO]             'higher_is_better': True,
# 2023-10-11 15:30:46 [INFO]             'tolerable_loss': 0.05,
# 2023-10-11 15:30:46 [INFO]             'absolute': None,
# 2023-10-11 15:30:46 [INFO]             'keys': <bound method AccuracyCriterion.keys of <neural_compressor.config.AccuracyCriterion object at 0x7cdec2380ac0>>,
# 2023-10-11 15:30:46 [INFO]             'relative': 0.05
# ...
